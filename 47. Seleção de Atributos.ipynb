# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import chi2, SelectKBest

# %%
anuncio = pd.read_csv('ad.data', header=None)
anuncio.shape
# Out:
# (3279, 1559)

# %%
X = anuncio.iloc[:, :-1].values
y = anuncio.iloc[:, -1].values

# %%
X
# Out:
# array([[125.    , 125.    ,   1.    , ...,   0.    ,   0.    ,   0.    ],
#        [ 57.    , 468.    ,   8.2105, ...,   0.    ,   0.    ,   0.    ],
#        [ 33.    , 230.    ,   6.9696, ...,   0.    ,   0.    ,   0.    ],
#        ...,
#        [ 23.    , 120.    ,   5.2173, ...,   0.    ,   0.    ,   0.    ],
#        [  0.    ,   0.    ,   0.    , ...,   0.    ,   0.    ,   0.    ],
#        [ 40.    ,  40.    ,   1.    , ...,   0.    ,   0.    ,   0.    ]])

# %%
y
# Out:
# array(['ad.', 'ad.', 'ad.', ..., 'nonad.', 'nonad.', 'nonad.'],
#       dtype=object)

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
model1 = GaussianNB()
model1.fit(X_treinamento, y_treinamento)

previsoes1 = model1.predict(X_teste)
print(accuracy_score(y_teste, previsoes1))
# Out:
# 0.7764227642276422

# %%
selecao = SelectKBest(chi2, k=7)
X_novo = selecao.fit_transform(X, y)
X_novo
# Out:
# array([[125.    , 125.    ,   1.    , ...,   1.    ,   0.    ,   1.    ],
#        [ 57.    , 468.    ,   8.2105, ...,   1.    ,   0.    ,   0.    ],
#        [ 33.    , 230.    ,   6.9696, ...,   0.    ,   0.    ,   0.    ],
#        ...,
#        [ 23.    , 120.    ,   5.2173, ...,   0.    ,   0.    ,   0.    ],
#        [  0.    ,   0.    ,   0.    , ...,   0.    ,   0.    ,   0.    ],
#        [ 40.    ,  40.    ,   1.    , ...,   0.    ,   0.    ,   0.    ]])

# %%
X_novo.shape
# Out:
# (3279, 7)

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X_novo, y, test_size=0.3, random_state=0)

# %%
model2 = GaussianNB()
model2.fit(X_treinamento, y_treinamento)

previsoes2 = model2.predict(X_teste)
print(accuracy_score(y_teste, previsoes2))
# Out:
# 0.9451219512195121
